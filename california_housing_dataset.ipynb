# %% [markdown]
# <a href="https://colab.research.google.com/github/mohsinhasan86/Excel-data-analysys/blob/main/california_housing_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/california_housing.csv')
df.head()
df.shape
df.columns
df.info()
df.isnull().sum()
df.duplicated().sum()
df = df.drop_duplicates()
df.duplicated().sum()
df.shape
df.isnull().sum() / len(df) * 100
df['total_bedrooms'] = df['total_bedrooms'].fillna(df['total_bedrooms'].median())
df['median_income'] = df['median_income'].fillna(df['median_income'].median())
df.isnull().sum()
df.shape
df.isnull().sum().sum()
df.describe()
df['ocean_proximity'].value_counts()
df['data_source_note'].value_counts()
(df['total_rooms'] <= 0).sum()
(df['total_bedrooms'] <= 0).sum()
(df['population'] <= 0).sum()
(df['households'] <= 0).sum()
(df['total_bedrooms'] <= 0).sum()
df['rooms_per_household'] = df['total_rooms'] / df['households']
df['bedrooms_per_room'] = df['total_bedrooms'] / df['total_rooms']

df['rooms_per_household'] = df['total_rooms'] / df['households']

df['bedrooms_per_room'] = df['total_bedrooms'] / df['total_rooms']

df['population_per_household'] = df['population'] / df['households']
df.to_csv('california_housing_cleaned.csv', index=False)
from google.colab import files

files.download('california_housing_cleaned.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2030 entries, 0 to 2029
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   respondent_id       2030 non-null   int64
#  1   longitude           2030 non-null   float64
#  2   latitude            2030 non-null   float64
#  3   housing_median_age  2030 non-null   int64
#  4   total_rooms         2030 non-null   int64
#  5   total_bedrooms      1929 non-null   float64
#  6   population          2030 non-null   int64
#  7   households          2030 non-null   int64
#  8   median_income       2010 non-null   float64
#  9   ocean_proximity     2030 non-null   object
#  10  data_source_note    2030 non-null   object
#  11  median_house_value  2030 non-null   float64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 190.4+ KB
